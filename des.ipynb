# %%
pip install pycrypto
# Out:
# Collecting pycrypto
#   Downloading https://files.pythonhosted.org/packages/60/db/645aa9af249f059cc3a368b118de33889219e0362141e75d4eaf6f80f163/pycrypto-2.6.1.tar.gz (446kB)
#      |████████████████████████████████| 450kB 9.8MB/s
# Building wheels for collected packages: pycrypto
#   Building wheel for pycrypto (setup.py) ... done
#   Created wheel for pycrypto: filename=pycrypto-2.6.1-cp36-cp36m-linux_x86_64.whl size=499957 sha256=c944bf47492a8f3a516965c6fa00679bd0b462a5ffcbf13f3ee0bedb10098506
#   Stored in directory: /root/.cache/pip/wheels/27/02/5e/77a69d0c16bb63c6ed32f5386f33a2809c94bd5414a2f6c196
# Successfully built pycrypto
# Installing collected packages: pycrypto
# Successfully installed pycrypto-2.6.1

# %%
from Crypto.Cipher import DES
from Crypto import Random
import base64


BS= DES.block_size 
MODE = DES.MODE_CBC
def pad(s):
    return s + (BS - len(s) % BS) * chr(BS - len(s) % BS)


def unpad(s):
    return s[:-ord(s[len(s)-1:])]


def enc(key,p):
	iv = Random.new().read(BS)
	cipher=DES.new(key,MODE,iv)

	p=pad(p)
	c=cipher.encrypt(p)
	msg = iv+c
	return base64.b64encode(msg)

def dec(key,msg):
	msg=base64.b64decode(msg)
	iv = msg[:BS]
	decipher=DES.new(key,MODE,iv)
	p = unpad(decipher.decrypt(msg[BS:]))
	return p


key=Random.new().read(8)
p='jayesh is best'
msg =enc(key,p)
print(msg)
print(dec(key,msg))
# Out:
# b'QPVi/n3PPxNAb3KaAev+jVZZp/JUI6Ba'
# b'jayesh is best'
